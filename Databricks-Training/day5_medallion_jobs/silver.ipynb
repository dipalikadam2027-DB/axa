-- %%
%python
dbutils.widgets.text("catalog","")
catalog=dbutils.widgets.get("catalog")

-- %%
%python
df=spark.read.table(f"{catalog}.dipali_bronze.sales")

-- %%
%python
df1=df.dropDuplicates().dropna().drop("ingestion_date","file_name","file_path","last_modified_ts")

-- %%
%python
df1.write.mode("overwrite").saveAsTable(f"{catalog}.dipali_silver.sales_cleaned")
