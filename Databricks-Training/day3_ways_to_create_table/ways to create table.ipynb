-- %%
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

-- %%
create table dev.dipali.adult_income as
select * from read_files("/Volumes/dev/naval/raw/csv/Adult+Census+Income.csv")

-- %%
create table dev.dipali.house_price as
select * from read_files("/Volumes/dev/naval/raw/house-price.parquet")

-- %%
create table dev.dipali.customers as 
select * from read_files("/Volumes/dev/naval/raw/customers.json")

-- %%
create table dev.dipali.customers_metadata as 
select *, current_timestamp() as ingestion_ts, _metadata.file_path as file_path, _metadata.file_name as file_name from read_files("/Volumes/dev/naval/raw/customers.json")

-- %% [markdown]
-- # Parameter using SQL

-- %%
SELECT * FROM IDENTIFIER(:catalog || '.' || :schema || '.' || :table)
