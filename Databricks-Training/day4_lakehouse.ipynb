-- %%
insert into dev.naval.alpha values (5,'Dipali', 'Pune')

-- %%
use catalog dev;
use schema dipali;

-- %%
create table alpha(id int, name string, city string);

-- %%
desc extended alpha

-- %%
desc detail alpha

-- %%
select * from alpha

-- %%
desc history alpha

-- %%
insert into alpha values (1, 'Dipali', 'Pune')

-- %%
insert into alpha values (4, 'Sagar', 'Pune'),(5,'Pawan','Pune')

-- %%
desc history alpha

-- %%
create table beta (ord_id int) using iceberg

-- %% [markdown]
-- # Time Travel

-- %%
select * from dev.dipali.alpha version as of 2

-- %%
delete from dev.dipali.alpha

-- %%
restore table dev.dipali.alpha to version as of 3

-- %%
select * from dev.dipali.alpha

-- %%
create table dev.dipali.alpha_e (id int) location 's3://jpmctraining/axa/dipali/alphae'
