-- %% [markdown]
-- # Getting started with Databricks Notebook

-- %%
select "RUN SQL"

-- %%
select * from samples.tpch.customer

-- %%
select * from samples.tpch.customer where customer.c_custkey=412446

-- %%
select * from samples.tpch.supplier order by s_suppkey desc limit 10
